# %% [markdown]
# # Introduction to Time Series Clustering
#
# ## Datos de precios de electricidad
#
# Actualización a febrero de 2024

# %%
# Dependencies
import pandas as pd
pd.set_option('display.max_columns', 100)
from pandas.plotting import scatter_matrix
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/benjamin/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#!pip install pip
#!pip install --upgrade seaborn
#!pip install --upgrade numpy

# %%
# Opciones de visualizació de cifras:
pd.options.display.float_format = '{:,.2f}'.format #'${:,.2f}'

# %% [markdown]
# ## Descarga de datos
#
# Datos reportados por la Secretaría de Salud sobre la COVID19. Los datos se publican diariamente y se pueden encontrar aquí.
#
# Los datos están en formato zip, dentro del archivo comprimido hay un archivo de tipo CSV.
#
# Los utilizaremoss sin descargarlos y descomprimirlos.
#
# Fuente: https://www.gob.mx/salud/documentos/datos-abiertos-bases-historicas-direccion-general-de-epidemiologia?idiom=es

# %%
# Cara renglón en este data set es una persona

df_2024 = pd.read_csv('https://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/historicos/2024/02/datos_abiertos_covid19_06.02.2024.zip', 
                  compression = 'zip', encoding = 'latin1')

df_2024.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2024-02-06      0aa89f       1      10           9     2
# 1          2024-02-06      0ed066       2      12          16     2
# 2          2024-02-06      7aeb5d       2      12           3     1
# 3          2024-02-06      64d705       1       6          18     1
# 4          2024-02-06      8b1a04       2       9          14     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0           15            9              3              1    2024-01-26
# 1           16           16             41              1    2023-03-09
# 2           15            3              3              1    2023-06-12
# 3           25           18             17              1    2023-01-19
# 4           14           14            120              2    2023-05-28
#
#   FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 0     2024-01-25  9999-99-99        97         2    31             1
# 1     2023-03-06  9999-99-99        97         2    28             1
# 2     2023-06-09  9999-99-99        97         2    77             1
# 3     2023-01-17  9999-99-99        97         2    82             1
# 4     2023-05-26  9999-99-99         2         2    80             1
#
#    EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0        97                   2         2         2     2     2         2
# 1        97                   2         2         2     2     2         2
# 2         2                   2         2         2     2     2         2
# 3         2                   2         2         2     2     2         2
# 4         2                   2         2         2     2     2         2
#
#    HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0             2         2               2         2              2
# 1             2         2               2         2              2
# 2             2         2               1         2              2
# 3             1         2               2         2              2
# 4             2         2               2         2              2
#
#    TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# 0           2          1                 1              2
# 1           1          2                 2             97
# 2           2          1                 2             97
# 3           2          2                 2             97
# 4           2         99                 1              4
#
#    TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  \
# 0                      2                  97                    7        99
# 1                      1                   2                    7        99
# 2                      1                   2                    7        99
# 3                      2                  97                    6        99
# 4                      2                  97                    6        99
#
#   PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 0           MÃ©xico          97   97
# 1           MÃ©xico          97   97
# 2           MÃ©xico          97   97
# 3           MÃ©xico          97   97
# 4           MÃ©xico          97    2

# %%
#

df_2024.tail()
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 1248560          2024-02-06     m00ee10       2      12          15     2
# 1248561          2024-02-06     m1cc581       2       3          15     1
# 1248562          2024-02-06     m0b0348       2      12          15     1
# 1248563          2024-02-06     m08f43c       2       3          15     2
# 1248564          2024-02-06     m1325ff       2       3          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 1248560           30           15             33              1    2023-08-30
# 1248561           20           15            999              1    2023-08-30
# 1248562            9           15            999              1    2023-08-30
# 1248563           15           15            999              1    2023-08-31
# 1248564           15           15            999              1    2023-09-04
#
#         FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 1248560     2023-08-30  9999-99-99        97        99    61             1
# 1248561     2023-08-30  9999-99-99        97        99    61             1
# 1248562     2023-08-30  9999-99-99        97        99    39             1
# 1248563     2023-08-31  9999-99-99        97        99    66             1
# 1248564     2023-09-04  9999-99-99        97        99    39             1
#
#          EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  \
# 1248560        97                  99        99         2     2     2
# 1248561         2                  99        99         2     2     2
# 1248562         2                  99        99         2     2     2
# 1248563        97                  99        99         1     1     2
# 1248564         2                  99        99         2     2     2
#
#          INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 1248560         2             2        98               2         2
# 1248561         2             2        98               2         2
# 1248562         2             2        98               2         2
# 1248563         2             2        98               2         2
# 1248564         2             2        98               2         2
#
#          RENAL_CRONICA  TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  \
# 1248560              2           2         99                 2
# 1248561              2           2         99                 2
# 1248562              2           2         99                 2
# 1248563              2           2         99                 2
# 1248564              2           2         99                 2
#
#          RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 1248560             97                      1                   2
# 1248561             97                      1                   2
# 1248562             97                      1                   2
# 1248563             97                      1                   2
# 1248564             97                      1                   2
#
#          CLASIFICACION_FINAL  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 1248560                    7        99           MÃ©xico          97   97
# 1248561                    7        99           MÃ©xico          97   97
# 1248562                    7        99           MÃ©xico          97   97
# 1248563                    7        99           MÃ©xico          97   97
# 1248564                    7        99           MÃ©xico          97   97

# %%
# Cara renglón en este data set es una persona

df_2022 = pd.read_csv('https://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/historicos/2022/COVID19MEXICO2022.zip', 
                  compression = 'zip', encoding = 'latin1')

df_2022.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2023-06-01      15ec76       1      12           5     2
# 1          2023-06-01      1ce5c6       2       6           9     2
# 2          2023-06-01      07e45f       1       6          12     1
# 3          2023-06-01      17d402       2      12           9     2
# 4          2023-06-01      0a392b       1      12           7     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0            5            5             35              1    2022-01-11
# 1            9            9             10              2    2022-02-02
# 2           12           12             29              1    2022-03-20
# 3            9            9              8              1    2022-06-25
# 4            7            7             19              1    2022-08-23
#
#   FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 0     2022-01-08  9999-99-99        97         2    26             1
# 1     2022-02-02  9999-99-99         2         2    70             1
# 2     2022-03-15  9999-99-99        97         2    82             1
# 3     2022-06-23  9999-99-99        97         2    25             1
# 4     2022-08-21  9999-99-99        97         2    36             1
#
#    EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0        97                   2         2         2     2     2         2
# 1        97                   2         2         2     2     2         2
# 2         2                   2         2         2     2     2         2
# 3        97                   2         2         2     2     2         2
# 4         2                   2         2         2     2     2         2
#
#    HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0             2         2               2         2              2
# 1             2         2               2         2              2
# 2             2         2               2         2              2
# 3             2         2               2         2              2
# 4             2         2               2         2              2
#
#    TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# 0           2          2                 2             97
# 1           2          2                 2             97
# 2           2          2                 2             97
# 3           2          2                 2             97
# 4           2          2                 2             97
#
#    TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  \
# 0                      1                   1                    3        99
# 1                      1                   2                    7        99
# 2                      2                  97                    6        99
# 3                      1                   2                    7        99
# 4                      2                  97                    6        99
#
#   PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 0           MÃ©xico          97   97
# 1           MÃ©xico          97    2
# 2           MÃ©xico          97   97
# 3           MÃ©xico          97   97
# 4           MÃ©xico          97   97

# %%
#

df_2022.tail()
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 6451939          2023-06-01      bc6fd3       1      12          12     1
# 6451940          2023-06-01      d5d7f8       1       4          12     2
# 6451941          2023-06-01      7c2109       1      12          30     1
# 6451942          2023-06-01      96f8da       2      12           9     1
# 6451943          2023-06-01      956890       2      12           8     2
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 6451939           12           12              1              2    2022-01-31
# 6451940           12           12              1              1    2022-01-19
# 6451941           30           30            136              1    2022-01-23
# 6451942            9            9              8              1    2022-01-27
# 6451943            8            8             50              1    2022-01-30
#
#         FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 6451939     2022-01-28  9999-99-99         2         1    31             1
# 6451940     2022-01-18  9999-99-99        97         2    53             1
# 6451941     2022-01-22  9999-99-99        97         2     2             1
# 6451942     2022-01-27  9999-99-99        97         2    55             1
# 6451943     2022-01-30  9999-99-99        97         2    11             1
#
#          EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  \
# 6451939         2                   2         2         2     2     2
# 6451940        97                   2         2         1     2     2
# 6451941         2                   2         2         2     2     2
# 6451942         2                   2         2         2     2     2
# 6451943        97                   2         2         2     2     2
#
#          INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 6451939         2             2         2               2         2
# 6451940         2             1         2               2         2
# 6451941         2             2         2               2         2
# 6451942         2             2         2               2         2
# 6451943         2             2         2               2         2
#
#          RENAL_CRONICA  TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  \
# 6451939              2           2          1                 1
# 6451940              2           2          1                 2
# 6451941              2           2          2                 2
# 6451942              2           2          2                 2
# 6451943              2           2          2                 2
#
#          RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 6451939              1                      1                   1
# 6451940             97                      1                   1
# 6451941             97                      1                   1
# 6451942             97                      1                   1
# 6451943             97                      1                   2
#
#          CLASIFICACION_FINAL  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 6451939                    3        99           MÃ©xico          97    2
# 6451940                    3        99           MÃ©xico          97   97
# 6451941                    3        99           MÃ©xico          97   97
# 6451942                    3        99           MÃ©xico          97   97
# 6451943                    7        99           MÃ©xico          97   97

# %%
# Cara renglón en este data set es una persona

df_2021 = pd.read_csv('https://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/historicos/2021/COVID19MEXICO2021.zip', 
                  compression = 'zip', encoding = 'latin1')

df_2021.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-08-09      z53cb3       2      12           9     2
# 1          2022-08-09      zze974       1       6          24     1
# 2          2022-08-09      zz7202       1      12          16     2
# 3          2022-08-09      z405fd       1      12           9     2
# 4          2022-08-09      z26b82       2      12           9     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0            9            9              2              1    2021-01-16
# 1           24           24             35              1    2021-02-28
# 2           16           16            112              1    2021-01-13
# 3            9            9             11              1    2021-01-25
# 4            9            9              7              1    2021-01-14
#
#   FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 0     2021-01-13  9999-99-99        97         2    26             1
# 1     2021-02-20  9999-99-99        97        99    34             1
# 2     2021-01-13  9999-99-99        97         2    41             1
# 3     2021-01-17  9999-99-99        97         2    25             1
# 4     2021-01-10  9999-99-99        97         2    20             1
#
#    EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0        97                   2         2         2     2     2         2
# 1         2                   2         2         2     2     2         2
# 2        97                   2         2         2     2     2         2
# 3        97                   2         2         2     2     2         2
# 4         2                   2         2         2     2     2         2
#
#    HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0             2         2               2         2              2
# 1             2         2               2         2              2
# 2             2         2               2         2              2
# 3             2         2               2         2              2
# 4             2         2               2         2              2
#
#    TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# 0           2          1                 2             97
# 1           2          1                 1              2
# 2           1          1                 1              2
# 3           2          1                 2             97
# 4           2          2                 2             97
#
#    TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  \
# 0                      1                   2                    7        99
# 1                      2                  97                    7        99
# 2                      2                  97                    7        99
# 3                      1                   2                    7        99
# 4                      1                   2                    7        99
#
#   PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 0           MÃ©xico          97   97
# 1           MÃ©xico          97   97
# 2           MÃ©xico          97   97
# 3           MÃ©xico          97   97
# 4           MÃ©xico          97   97

# %%
#

df_2021.tail()
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 8830340          2022-08-09     m0f93ef       2      12          15     1
# 8830341          2022-08-09     m08e5a6       2      12          15     1
# 8830342          2022-08-09     m0bea6e       2      12          15     1
# 8830343          2022-08-09     m00eab3       2      12          15     2
# 8830344          2022-08-09     m0bfb28       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 8830340           15           15             58              1    2021-10-18
# 8830341           13           15             58              1    2021-10-18
# 8830342           15           15             58              1    2021-10-18
# 8830343            9           15             60              1    2021-12-18
# 8830344            9           15             60              1    2021-12-18
#
#         FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 8830340     2021-10-18  9999-99-99        97        99    33             1
# 8830341     2021-10-18  9999-99-99        97        99    43             1
# 8830342     2021-10-18  9999-99-99        97        99    49             1
# 8830343     2021-12-14  9999-99-99        97        99    48             1
# 8830344     2021-12-14  9999-99-99        97        99    52             1
#
#          EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  \
# 8830340         2                  99        99         2     2     2
# 8830341         2                  99        99         2     2     2
# 8830342         2                  99        99         2     2     2
# 8830343        97                  99        99         2     2     2
# 8830344        98                  99        99         2     2     2
#
#          INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 8830340         2             2        98               2         2
# 8830341         2             2        98               2         2
# 8830342         2             2        98               2         2
# 8830343         2             2        98               2         2
# 8830344         2             2        98               2         2
#
#          RENAL_CRONICA  TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  \
# 8830340              2           2         99                 2
# 8830341              2           2         99                 2
# 8830342              2           2         99                 2
# 8830343              2           2         99                 2
# 8830344              2           2         99                 2
#
#          RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 8830340             97                      1                   2
# 8830341             97                      1                   2
# 8830342             97                      1                   2
# 8830343             97                      1                   2
# 8830344             97                      1                   2
#
#          CLASIFICACION_FINAL  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 8830340                    7        99           MÃ©xico          97   97
# 8830341                    7        99           MÃ©xico          97   97
# 8830342                    7        99           MÃ©xico          97   97
# 8830343                    7        99           MÃ©xico          97   97
# 8830344                    7        99           MÃ©xico          97   97

# %%
# Cara renglón en este data set es una persona

df_2020 = pd.read_csv('https://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/historicos/2020/COVID19MEXICO2020.zip', 
                  compression = 'zip', encoding = 'latin1')

df_2020.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2021-10-31      z4d6fe       1       6          24     1
# 1          2021-10-31      z2a3cf       1       6          24     2
# 2          2021-10-31      z1e370       1      12          14     1
# 3          2021-10-31      z3bf80       2      12           8     2
# 4          2021-10-31      zz7067       1      12           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0           24           24             28              1    2020-12-06
# 1           24           24             28              1    2020-02-20
# 2           14           14             85              1    2020-04-22
# 3            8            8             37              1    2020-07-28
# 4            9            9              7              1    2020-08-18
#
#   FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 0     2020-11-30  9999-99-99        97         2    55             1
# 1     2020-02-18  9999-99-99        97         2    59             1
# 2     2020-04-18  9999-99-99        97         2    42             1
# 3     2020-07-20  9999-99-99        97         2    35             1
# 4     2020-08-17  9999-99-99        97         2    51             1
#
#    EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0         2                   2         2         1     2     2         2
# 1        97                   2         2         2     2     2         2
# 2         2                   2         2         2     2     1         2
# 3        97                   2         2         2     2     2         2
# 4        97                   2         2         2     2     2         2
#
#    HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0             2         2               2         2              2
# 1             2         2               2         2              2
# 2             2         2               2         2              2
# 3             2         2               2         2              2
# 4             1         2               2         2              2
#
#    TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# 0           2          2                 1              1
# 1           2          1                 2             97
# 2           2          2                 1              2
# 3           2          2                 1              1
# 4           2          2                 1              2
#
#    TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  \
# 0                      2                  97                    3        99
# 1                      2                  97                    6        99
# 2                      2                  97                    7        99
# 3                      2                  97                    3        99
# 4                      2                  97                    7        99
#
#   PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 0           MÃ©xico          97   97
# 1           MÃ©xico          97   97
# 2           MÃ©xico          97   97
# 3           MÃ©xico          97   97
# 4           MÃ©xico          97   97

# %%
#

df_2020.tail()
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 3868391          2021-10-31      94d648       2       9           9     1
# 3868392          2021-10-31      bb6edb       2       9           9     2
# 3868393          2021-10-31      7d32d9       2       9           9     2
# 3868394          2021-10-31      660ba7       1       4           9     1
# 3868395          2021-10-31      52b2e6       2       4           9     2
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 3868391           15           15             58              2    2020-12-17
# 3868392           15           15             25              2    2020-04-27
# 3868393            9            9              7              2    2020-12-05
# 3868394            9            9              7              2    2020-09-11
# 3868395            9           15             57              2    2020-04-29
#
#         FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 3868391     2020-12-14  2020-12-19         2         1    83             1
# 3868392     2020-04-15  2020-04-28         2         1    36             1
# 3868393     2020-12-01  2020-12-08         1         1    82             1
# 3868394     2020-09-09  2020-09-12         2         2    40             1
# 3868395     2020-04-29  2020-05-14         2         1    48             1
#
#          EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  \
# 3868391         2                   2         2         2     2     2
# 3868392        97                   2         2         2     2     2
# 3868393        97                   2         2         2     2     2
# 3868394         2                   2         2         2     2     2
# 3868395        97                   2         2         2     2     2
#
#          INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 3868391         2             2         2               2         2
# 3868392         2             2         2               2         2
# 3868393         2             2         2               2         2
# 3868394         2             2         2               2         2
# 3868395         2             1         1               2         2
#
#          RENAL_CRONICA  TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  \
# 3868391              2           2          2                 2
# 3868392              2           2          1                 2
# 3868393              2           2          1                 2
# 3868394              2           2          2                 2
# 3868395              2           1          2                 2
#
#          RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 3868391             97                      2                  97
# 3868392             97                      2                  97
# 3868393             97                      2                  97
# 3868394             97                      2                  97
# 3868395             97                      2                  97
#
#          CLASIFICACION_FINAL  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 3868391                    2        99           MÃ©xico          97    2
# 3868392                    2        99           MÃ©xico          97    2
# 3868393                    2        99           MÃ©xico          97    1
# 3868394                    2        99           MÃ©xico          97    2
# 3868395                    2        99           MÃ©xico          97    2

# %%
# Número de datos

df_2024.shape, df_2022.shape, df_2021.shape, df_2020.shape
# Out:
# ((1248565, 40), (6451944, 40), (8830345, 40), (3868396, 40))

# %%
# Concatenamos la información

df = pd.concat([ df_2020, df_2021, df_2022, df_2024 ], ignore_index = True )

df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2021-10-31      z4d6fe       1       6          24     1
# 1          2021-10-31      z2a3cf       1       6          24     2
# 2          2021-10-31      z1e370       1      12          14     1
# 3          2021-10-31      z3bf80       2      12           8     2
# 4          2021-10-31      zz7067       1      12           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0           24           24             28              1    2020-12-06
# 1           24           24             28              1    2020-02-20
# 2           14           14             85              1    2020-04-22
# 3            8            8             37              1    2020-07-28
# 4            9            9              7              1    2020-08-18
#
#   FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 0     2020-11-30  9999-99-99        97         2    55             1
# 1     2020-02-18  9999-99-99        97         2    59             1
# 2     2020-04-18  9999-99-99        97         2    42             1
# 3     2020-07-20  9999-99-99        97         2    35             1
# 4     2020-08-17  9999-99-99        97         2    51             1
#
#    EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0         2                   2         2         1     2     2         2
# 1        97                   2         2         2     2     2         2
# 2         2                   2         2         2     2     1         2
# 3        97                   2         2         2     2     2         2
# 4        97                   2         2         2     2     2         2
#
#    HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0             2         2               2         2              2
# 1             2         2               2         2              2
# 2             2         2               2         2              2
# 3             2         2               2         2              2
# 4             1         2               2         2              2
#
#    TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# 0           2          2                 1              1
# 1           2          1                 2             97
# 2           2          2                 1              2
# 3           2          2                 1              1
# 4           2          2                 1              2
#
#    TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  \
# 0                      2                  97                    3        99
# 1                      2                  97                    6        99
# 2                      2                  97                    7        99
# 3                      2                  97                    3        99
# 4                      2                  97                    7        99
#
#   PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 0           MÃ©xico          97   97
# 1           MÃ©xico          97   97
# 2           MÃ©xico          97   97
# 3           MÃ©xico          97   97
# 4           MÃ©xico          97   97

# %%
# Número de datos

df.shape, 1248565 + 6451944 + 8830345 + 3868396
# Out:
# ((20399250, 40), 20399250)

# %%
# Nombres de las columnas

df.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
# Tipo de caso que analizaremos y cómo los clasificaremos

df['CLASIFICACION_FINAL'].value_counts()
# Out:
# CLASIFICACION_FINAL
# 7    11803665
# 3     7321780
# 6      768941
# 1      377726
# 5       99065
# 2       15995
# 4       12078
# Name: count, dtype: int64

# %% [markdown]
# ## Claves de la 'CLASIFICACION FINAL'
#
#
# * 1 = CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA: aplica cuando el caso informó ser contacto de un positivo a COVID-19 y al caso no se le tomo muestra o la muestra resultó no válida
# * 2 = CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN: aplica para defunciones que no se le tomó muestra o sí se tomó muestra, pero la muestra resultó no válida
# * 3 = CASO DE SARS-COV-2 CONFIRMADO POR LABORATORIO: aplica  cuanndo el caso tiene muestra y resultó positiva a SARS-CoV-2, sin importar si el caso tienen asociación clínica epidemiológica
# * 4 = INVÁLIDO POR LABORATORIO: aplica cuando el caso no tienen asociación clínico epidemiológica, ni dictaminación a COVID-19, se le tomó muestra y esta resultó no válida
# * 5 = NO REALIZADO POR LABORATORIO: aplica cuando el caso no tienen asociación clínico epidemiológica, ni dictaminación a COVID-19 y se le tomó muestra y esta no se procesó
# * 6 = CASO SOSPECHOSO: aplica cuando el caso no tienen asociación clínico epidemiológica, ni dictaminación a COVID-19 y no se le tomó muestra, o se le tomó muestra y está pendiente de resultado, sin importar otra condición
# * 7 = NEGATIVO A SARS-COV-2 POR LABORATORIO: aplica cuando el caso se le tomo muestra y esta resultó negativa a SARS-COV-2 o positiva a cualquier otro virus respiratorio (Influenza, VSR, Bocavirus, otros) sin importar que este caso tenga asociación clínico epidemiológica o dictaminación a COVID-19

# %% [markdown]
# ## Clasificando los casos de acuerdo a su calidad de confirmados, sospechosos o negativos
#
# Para checar consistencia: https://datos.covid-19.conacyt.mx/

# %% [markdown]
# ## Casos negativos
#
# * 7 = NEGATIVO A SARS-COV-2 POR LABORATORIO: aplica cuando el caso se le tomo muestra y esta resultó negativa a SARS-COV-2 o positiva a cualquier otro virus respiratorio (Influenza, VSR, Bocavirus, otros) sin importar que este caso tenga asociación clínico epidemiológica o dictaminación a COVID-19

# %%
# 

Negativos = df[ df["CLASIFICACION_FINAL"] == 7 ]

Negativos.shape
# Out:
# (11803665, 40)

# %% [markdown]
# ## Casos confirmados
#
# * 1 = CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA: aplica cuando el caso informó ser contacto de un positivo a COVID-19 y al caso no se le tomo muestra o la muestra resultó no válida
# * 2 = CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN: aplica para defunciones que no se le tomó muestra o sí se tomó muestra, pero la muestra resultó no válida
# * 3 = CASO DE SARS-COV-2 CONFIRMADO POR LABORATORIO: aplica  cuanndo el caso tiene muestra y resultó positiva a SARS-CoV-2, sin importar si el caso tienen asociación clínica epidemiológica

# %%
#

Confirmados = df[ df["CLASIFICACION_FINAL"].isin( [1, 2, 3] ) ]

Confirmados.shape
# Out:
# (7715501, 40)

# %% [markdown]
# Gráfica - Histograma por sexo

# %%
# CLAVE DESCRIPCIÓN
# 1 - MUJER
# 2 - HOMBRE

Confirmados['SEXO'].value_counts()
# Out:
# SEXO
# 1    4146266
# 2    3569235
# Name: count, dtype: int64

# %%
Confirmados[Confirmados['SEXO'] == 2]['EDAD']
# Out:
# 3           35
# 20          37
# 42          40
# 45          56
# 49          26
#             ..
# 20399215    31
# 20399227    27
# 20399233    26
# 20399240    68
# 20399242    50
# Name: EDAD, Length: 3569235, dtype: int64

# %%
# Histograma:

H = Confirmados[Confirmados['SEXO'] == 2]['EDAD']

M = Confirmados[Confirmados['SEXO'] == 1]['EDAD']

plt.figure(figsize=(10, 6))  

# Añadir los histogramas. alpha es para la opacidad.
plt.hist(H, bins=30, alpha=0.75, label='Hombres')
plt.hist(M, bins=30, alpha=0.75, label='Mujeres')

# Configurar las leyendas
plt.legend(loc = 'upper right')

# Título y etiquetas
plt.title('Casos confirmados acumulados por edad', fontsize=16, fontname='Times New Roman', pad=20)
plt.xlabel('Edad', fontsize=14, fontname='Times New Roman')
plt.ylabel('Frecuencia', fontsize=14, fontname='Times New Roman')

plt.show()

# %%
#

Confirmados["FECHA_SINTOMAS"].value_counts()
# Out:
# FECHA_SINTOMAS
# 2022-01-10    80705
# 2022-01-17    70285
# 2022-01-11    61831
# 2022-01-12    59844
# 2022-01-18    59012
#               ...
# 2020-02-25        1
# 2020-02-23        1
# 2020-02-26        1
# 2020-02-19        1
# 2024-02-03        1
# Name: count, Length: 1443, dtype: int64

# %%
#

Confirmados["FECHA_INGRESO"].value_counts()
# Out:
# FECHA_INGRESO
# 2022-01-17    81302
# 2022-01-12    75684
# 2022-01-18    75305
# 2022-01-13    74978
# 2022-01-14    73472
#               ...
# 2023-12-09        3
# 2020-02-28        2
# 2020-03-01        2
# 2020-02-29        2
# 2024-02-04        1
# Name: count, Length: 1439, dtype: int64

# %% [markdown]
# ## Casos sospechosos
#
# * 6 = CASO SOSPECHOSO: aplica cuando el caso no tienen asociación clínico epidemiológica, ni dictaminación a COVID-19 y no se le tomó muestra, o se le tomó muestra y está pendiente de resultado, sin importar otra condición

# %%
#

Sospechosos = df[ df["CLASIFICACION_FINAL"] == 6 ]

Sospechosos.shape
# Out:
# (768941, 40)

# %% [markdown]
# ## Defunciones
#
# La base de datos no cuenta con una columna que indique de forma categórica si el caso falleció o no.
#
# Podemos obtener este dato de forma indirecta; utillizando la fecha de defunción en "FECHA_DEF"

# %%
#

df["FECHA_DEF"].value_counts()
# Out:
# FECHA_DEF
# 9999-99-99    19953759
# 2021-01-20        1738
# 2021-01-25        1719
# 2021-01-19        1691
# 2021-01-21        1673
#                 ...
# 2020-01-06           3
# 2020-01-05           2
# 2020-01-02           1
# 2020-01-04           1
# 2024-02-05           1
# Name: count, Length: 1496, dtype: int64

# %%
#
#Confirmados = df[ df["CLASIFICACION_FINAL"].isin( [1, 2, 3] ) ]


Defunciones = df[ ( df["CLASIFICACION_FINAL"].isin( [1, 2, 3] ) ) & ( df["FECHA_DEF"] != "9999-99-99"  ) ]
Defunciones.shape
# Out:
# (335135, 40)

# %% [markdown]
# Gráfica - Histograma por sexo

# %%
# CLAVE	DESCRIPCIÓN
# 1 - MUJER
# 2 - HOMBRE

Defunciones['SEXO'].value_counts()
# Out:
# SEXO
# 2    206209
# 1    128926
# Name: count, dtype: int64

# %%
Defunciones[Defunciones['SEXO'] == 2]['EDAD']
# Out:
# 138         58
# 209         53
# 24059       47
# 24798       39
# 24993       63
#             ..
# 20388756    77
# 20389332    50
# 20389335    38
# 20390464    82
# 20398825    83
# Name: EDAD, Length: 206209, dtype: int64

# %%
# Histograma:

H = Defunciones[(Defunciones['SEXO'] == 2) ]['EDAD']

M = Defunciones[(Defunciones['SEXO'] == 1) ]['EDAD']

plt.figure(figsize=(10, 6))  

# Añadir los histogramas. alpha es para la opacidad.
plt.hist(H, bins=30, alpha=0.75, label='Hombres')
plt.hist(M, bins=30, alpha=0.75, label='Mujeres')

# Configurar las leyendas
plt.legend(loc = 'upper right')

# Título y etiquetas
plt.title('Defunciones acumuladas por edad (TODA LA PANDEMIA)', fontsize=16, fontname='Times New Roman', pad=20)
plt.xlabel('Edad', fontsize=14, fontname='Times New Roman')
plt.ylabel('Frecuencia', fontsize=14, fontname='Times New Roman')

plt.show()

# %% [markdown]
# ## Serie de casos confirmados diarios

# %%
# Agrupando por fechas: 

Grupos_fecha = Confirmados.groupby("FECHA_SINTOMAS")

# Guardamos como Data Frame

Serie_Confirmados = Grupos_fecha.size().to_frame("Confirmados").reset_index()

# Convertimos a tipo de dato fecha la columna:

Serie_Confirmados["Fecha"] = pd.to_datetime(Serie_Confirmados["FECHA_SINTOMAS"])

Serie_Confirmados.head()
# Out:
#   FECHA_SINTOMAS  Confirmados      Fecha
# 0     2020-02-19            1 2020-02-19
# 1     2020-02-22            2 2020-02-22
# 2     2020-02-23            1 2020-02-23
# 3     2020-02-25            1 2020-02-25
# 4     2020-02-26            1 2020-02-26

# %%
# Agrupando por fechas: 

Grupos_fecha = Confirmados.groupby("FECHA_INGRESO")

# Guardamos como Data Frame

Serie_Confirmados_B = Grupos_fecha.size().to_frame("Confirmados").reset_index()

Serie_Confirmados_B = Serie_Confirmados_B.rename(columns = {'Confirmados': 'Confirmados_Ing'})

# Convertimos a tipo de dato fecha la columna:

Serie_Confirmados_B["Fecha"] = pd.to_datetime(Serie_Confirmados_B["FECHA_INGRESO"])

Serie_Confirmados_B.head()
# Out:
#   FECHA_INGRESO  Confirmados_Ing      Fecha
# 0    2020-02-27                4 2020-02-27
# 1    2020-02-28                2 2020-02-28
# 2    2020-02-29                2 2020-02-29
# 3    2020-03-01                2 2020-03-01
# 4    2020-03-02                5 2020-03-02

# %% [markdown]
# ## Serie de defunciones diarias
#
# ### A. Por fecha de sintomas

# %%
# Agrupando por fechas: 

Grupos_fecha = Defunciones.groupby("FECHA_SINTOMAS")

# Guardamos como Data Frame

Serie_Defunciones_A = Grupos_fecha.size().to_frame("Defunciones").reset_index()

# Convertimos a tipo de dato fecha la columna:

Serie_Defunciones_A["Fecha"] = pd.to_datetime(Serie_Defunciones_A["FECHA_SINTOMAS"])

Serie_Defunciones_A.head()
# Out:
#   FECHA_SINTOMAS  Defunciones      Fecha
# 0     2020-02-26            1 2020-02-26
# 1     2020-02-29            1 2020-02-29
# 2     2020-03-01            1 2020-03-01
# 3     2020-03-02            2 2020-03-02
# 4     2020-03-03            2 2020-03-03

# %% [markdown]
# ### B. Por fecha de defunción

# %%
# Agrupando por fechas: 

Grupos_fecha = Defunciones.groupby("FECHA_DEF")

# Guardamos como Data Frame

Serie_Defunciones_B = Grupos_fecha.size().to_frame("Defunciones").reset_index()

# Convertimos a tipo de dato fecha la columna:

Serie_Defunciones_B["Fecha"] = pd.to_datetime(Serie_Defunciones_B["FECHA_DEF"])

Serie_Defunciones_B.head()
# Out:
#     FECHA_DEF  Defunciones      Fecha
# 0  2020-03-18            3 2020-03-18
# 1  2020-03-20            1 2020-03-20
# 2  2020-03-22            2 2020-03-22
# 3  2020-03-23            1 2020-03-23
# 4  2020-03-24            3 2020-03-24

# %% [markdown]
# ## Serie de casos sospechosos diarios

# %%
# Agrupando por fechas: 

Grupos_fecha = Sospechosos.groupby("FECHA_SINTOMAS")

# Guardamos como Data Frame

Serie_Sospechosos = Grupos_fecha.size().to_frame("Sospechosos").reset_index()

# Convertimos a tipo de dato fecha la columna:

Serie_Sospechosos["Fecha"] = pd.to_datetime(Serie_Sospechosos["FECHA_SINTOMAS"])

Serie_Sospechosos.head()
# Out:
#   FECHA_SINTOMAS  Sospechosos      Fecha
# 0     2020-01-01          132 2020-01-01
# 1     2020-01-02          113 2020-01-02
# 2     2020-01-03          112 2020-01-03
# 3     2020-01-04          107 2020-01-04
# 4     2020-01-05          163 2020-01-05

# %% [markdown]
# ## Graficando

# %%
# Preparamos DataFrame's

conf = Serie_Confirmados[['Confirmados', 'Fecha']] # Fecha de síntomas

conf_b = Serie_Confirmados_B[['Confirmados_Ing', 'Fecha']] # Fecha de ingreso

defun_a = Serie_Defunciones_A[['Defunciones', 'Fecha']] # Fecha de síntomas

defun_b = Serie_Defunciones_B[['Defunciones', 'Fecha']] # Fecha de defunción

sosp = Serie_Sospechosos[['Sospechosos', 'Fecha']] # Fecha de síntomas

# %%
# Unimos las series: 

# Confirmados + Confirmados (con fecha de ingreso)
Series_Casos = pd.merge(conf, conf_b, how = 'outer', on = 'Fecha')

# Confirmados + Defunciones (con fecha de síntomas)
Series_Casos = pd.merge(Series_Casos, defun_a, how = 'outer', on = 'Fecha')

# Renombramos serie defunciones por fecha de síntomas
Series_Casos = Series_Casos.rename(columns = {'Defunciones': 'Defunciones_Sint'})

# Confirmados + Defunciones (con fecha de síntomas) + Defunciones (con fecha de muerte)
Series_Casos = pd.merge(Series_Casos, defun_b, how = 'outer', on = 'Fecha')

# Renombramos serie defunciones por fecha de muerte
Series_Casos = Series_Casos.rename(columns = {'Defunciones': 'Defunciones_Muer'})

# Confirmados + Defunciones (con fecha de síntomas) + Defunciones (con fecha de muerte) + Sospechosos
Series_Casos = pd.merge(Series_Casos, sosp, how = 'outer', on = 'Fecha')

#Series_Casos = Series_Casos.sort_values(by = 'Fecha', ascending = False)

Series_Casos.head()
# Out:
#    Confirmados      Fecha  Confirmados_Ing  Defunciones_Sint  \
# 0         1.00 2020-02-19              NaN               NaN
# 1         2.00 2020-02-22              NaN               NaN
# 2         1.00 2020-02-23              NaN               NaN
# 3         1.00 2020-02-25              NaN               NaN
# 4         1.00 2020-02-26              NaN              1.00
#
#    Defunciones_Muer  Sospechosos
# 0               NaN          217
# 1               NaN          224
# 2               NaN          238
# 3               NaN          241
# 4               NaN          197

# %%
# Ordenamos y reemplazamos nulos por ceros (0)

#Series_Casos = Series_Casos.fillna(0)

Series_Casos = Series_Casos.sort_values(by = 'Fecha', ascending = True).reset_index()

Series_Casos = Series_Casos[['Fecha', 'Confirmados', 'Confirmados_Ing', 'Sospechosos', 'Defunciones_Sint', 'Defunciones_Muer']]

Series_Casos
# Out:
#           Fecha  Confirmados  Confirmados_Ing  Sospechosos  Defunciones_Sint  \
# 0    2020-01-01          NaN              NaN          132               NaN
# 1    2020-01-02          NaN              NaN          113               NaN
# 2    2020-01-03          NaN              NaN          112               NaN
# 3    2020-01-04          NaN              NaN          107               NaN
# 4    2020-01-05          NaN              NaN          163               NaN
# ...         ...          ...              ...          ...               ...
# 1492 2024-02-01        18.00            71.00          314               NaN
# 1493 2024-02-02         7.00            33.00          112               NaN
# 1494 2024-02-03         1.00            10.00           59               NaN
# 1495 2024-02-04          NaN             1.00           53               NaN
# 1496 2024-02-05          NaN              NaN            6               NaN
#
#       Defunciones_Muer
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 1492              2.00
# 1493              2.00
# 1494              1.00
# 1495               NaN
# 1496              1.00
#
# [1497 rows x 6 columns]

# %%
# Series TODAS

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Confirmados'], label='Confirmados', color='darkblue')
plt.plot(Series_Casos['Fecha'], Series_Casos['Sospechosos'], label='Sospechosos', color='orange')
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Sint'], label='Defunciones por fecha de síntomas', color='darkred')
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Muer'], label='Defunciones por fecha de muerte', color='darkgreen')

# Configura el título y las leyendas
plt.title('Casos Confirmados y Sospechosos, y Defunciones (por fecha de síntomas y defunción)')
plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=0)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
# Series TODAS - Medias Móviles

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Confirmados'].rolling(window = 7).mean()/1000, label='Confirmados', color='darkblue')
plt.plot(Series_Casos['Fecha'], Series_Casos['Sospechosos'].rolling(window = 7).mean()/1000, label='Sospechosos', color='orange')
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Sint'].rolling(window = 7).mean()/1000, label='Defunciones por fecha de síntomas', color='darkred')
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Muer'].rolling(window = 7).mean()/1000, label='Defunciones por fecha de muerte', color='darkgreen')

# Configura el título y las leyendas
plt.title('Casos Confirmados y Sospechosos, y Defunciones (por fecha de síntomas y defunción) (en miles)')
plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=0)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
# Series Confirmados

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Confirmados']/1000, label='Confirmados', color='darkblue')

# Configura el título y las leyendas
plt.title('Evolución de los casos confirmados (por fecha de síntomas) - en miles')
#plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=0)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
# Sanity Check

sum(Series_Casos[Series_Casos['Fecha'] <= '2024-01-01']['Confirmados'].fillna(0))
# Out:
# 7713630.0

# %%
# Series Confirmados Medias Móviles

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Confirmados'].rolling(window = 7).mean()/1000, label='Confirmados', color='darkblue')

# Configura el título y las leyendas
plt.title('Evolución de los casos confirmados (por fecha de síntomas y media mólvil 7 días) - en miles')
#plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=45)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
# Series Confirmados ACUMULADOS

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Confirmados'].fillna(0).cumsum()/1000000, label='Confirmados', color='darkblue')

# Configura el título y las leyendas
plt.title('Casos confirmados acumulados (por fecha de síntomas) - en millones')
#plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=45)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
# Series Defunciones (fecha síntomas y fecha de defunción)

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Sint']/1000, label='Defunciones por fecha de síntomas', color='darkred')
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Muer']/1000, label='Defunciones por fecha de muerte', color='darkgreen')

# Configura el título y las leyendas
plt.title('Evolución de las defunciones (por fecha de síntomas y por fecha de defunción) - en miles')
plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=0)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
# Series Defunciones Medias Móviles

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Sint'].rolling(window = 7).mean()/1000, label='Defunciones por fecha de síntomas', color='darkred')
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Muer'].rolling(window = 7).mean()/1000, label='Defunciones por fecha de muerte', color='darkgreen')

# Configura el título y las leyendas
plt.title('Evolución de las defunciones (por fecha de síntomas y por fecha de defunción y media móvil 7 días) - en miles')
plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=0)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
# Series Defunciones TODAS ACUMULADAS

plt.figure(figsize=(10, 6)) 

# Agrega cada serie de datos como una línea en el gráfico
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Sint'].fillna(0).cumsum()/1000, label='Defunciones por fecha de síntomas', color='darkred')
plt.plot(Series_Casos['Fecha'], Series_Casos['Defunciones_Muer'].fillna(0).cumsum()/1000, label='Defunciones por fecha de muerte', color='darkgreen')

# Configura el título y las leyendas
plt.title('Defunciones acumuladas (por fecha de síntomas y por fecha de defunción) - en miles')
plt.legend()

# Formato de la fecha en el eje X
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.AutoDateLocator())
plt.xticks(rotation=0)  # Rota las fechas para mejor lectura

# Muestra el gráfico
plt.tight_layout()  
plt.show()

# %%
#

Series_Casos.head()
# Out:
#        Fecha  Confirmados  Confirmados_Ing  Sospechosos  Defunciones_Sint  \
# 0 2020-01-01          NaN              NaN          132               NaN
# 1 2020-01-02          NaN              NaN          113               NaN
# 2 2020-01-03          NaN              NaN          112               NaN
# 3 2020-01-04          NaN              NaN          107               NaN
# 4 2020-01-05          NaN              NaN          163               NaN
#
#    Defunciones_Muer
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# To CSV:

#Series_Casos.to_csv('Series_Casos.csv', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# ## Algoritmos de agrupamiento (clustering)
#
# Sabemos que los algoritmos pertenecientes a la familia del Aprendizaje No Supervisado no tienen ninguna variable que predecir ligada a los datos. En lugar de tener una salida, los datos solo tienen una entrada que serían múltiples variables que describen los datos. Aquí es donde entra en juego la agrupación.
#
# Clustering es la tarea de agrupar un conjunto de objetos de manera que los objetos del mismo grupo sean más similares entre sí que a los objetos de otros grupos. La similitud es una métrica que refleja la fuerza de la relación entre dos objetos de datos.
#
# La agrupación en clústeres se utiliza principalmente (pero no exclusivamente) para la exploración de datos. Tiene múltiples usos en muchos campos, como el machine learning, el reconocimiento de patrones, el análisis de imágenes, la recuperación de información, la bioinformática, la compresión de datos y los gráficos por computadora.
#
# Hacemos un repaso de esas técnicas.
#
# ### K-medias
#
# Existen muchos modelos de agrupación. Revisaremos los más populares. A pesar de su simplicidad, K-means se utiliza ampliamente para la agrupación en clústeres en muchas aplicaciones de ciencia de datos, lo que es especialmente útil si necesita descubrir rápidamente información a partir de datos sin etiquetar. En este notebook, vemos cómo utilizar k-Means para la segmentación de casos.

# %%
#Confirmados, Sospechosos, Defunciones
# Definición de catalógos:
ESTADO = ['AGUASCALIENTES', 'BAJA CALIFORNIA', 'BAJA CALIFORNIA SUR', 'CAMPECHE', 'COAHUILA DE ZARAGOZA', 
          'COLIMA', 'CHIAPAS', 'CHIHUAHUA', 'CIUDAD DE MÉXICO', 'DURANGO', 'GUANAJUATO', 'GUERRERO', 'HIDALGO', 
          'JALISCO', 'MÉXICO', 'MICHOACÁN DE OCAMPO', 'MORELOS', 'NAYARIT', 'NUEVO LEÓN', 'OAXACA', 'PUEBLA', 
          'QUERÉTARO', 'QUINTANA ROO', 'SAN LUIS POTOSÍ', 'SINALOA', 'SONORA', 'TABASCO', 'TAMAULIPAS', 
          'TLAXCALA', 'VERACRUZ DE IGNACIO DE LA LLAVE', 'YUCATÁN', 'ZACATECAS']

ABREVIATURA = ['AS', 'BC', 'BS', 'CC', 'CL', 'CM', 'CS', 'CH', 'DF', 'DG', 'GT', 'GR', 'HG', 'JC', 'MC', 'MN',
               'MS', 'NT', 'NL', 'OC', 'PL', 'QT', 'QR', 'SP', 'SL', 'SR', 'TC', 'TS', 'TL', 'VZ', 'YN', 'ZS']
#

# %%
#

Defunciones_KM = Defunciones

Defunciones_KM.shape
# Out:
# (335135, 40)

# %%
# Variable de Días

Defunciones_KM['Dias_Ing'] = ( pd.to_timedelta( 
                        pd.to_datetime( Defunciones_KM['FECHA_INGRESO'], format = '%Y-%m-%d' ) - \
                        pd.to_datetime( Defunciones_KM['FECHA_SINTOMAS'], format = '%Y-%m-%d' ) 
                   ).dt.total_seconds() / 3600 ) / 24

Defunciones_KM['Dias_Def'] = ( pd.to_timedelta( 
                        pd.to_datetime( Defunciones_KM['FECHA_DEF'], format = '%Y-%m-%d' ) - \
                        pd.to_datetime( Defunciones_KM['FECHA_SINTOMAS'], format = '%Y-%m-%d' ) 
                   ).dt.total_seconds() / 3600 ) / 24

# %%
#

Defunciones_KM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 335135 entries, 77 to 20398825
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   FECHA_ACTUALIZACION    335135 non-null  object
#  1   ID_REGISTRO            335135 non-null  object
#  2   ORIGEN                 335135 non-null  int64
#  3   SECTOR                 335135 non-null  int64
#  4   ENTIDAD_UM             335135 non-null  int64
#  5   SEXO                   335135 non-null  int64
#  6   ENTIDAD_NAC            335135 non-null  int64
#  7   ENTIDAD_RES            335135 non-null  int64
#  8   MUNICIPIO_RES          335135 non-null  int64
#  9   TIPO_PACIENTE          335135 non-null  int64
#  10  FECHA_INGRESO          335135 non-null  object
#  11  FECHA_SINTOMAS         335135 non-null  object
#  12  FECHA_DEF              335135 non-null  object
#  13  INTUBADO               335135 non-null  int64
#  14  NEUMONIA               335135 non-null  int64
#  15  EDAD                   335135 non-null  int64
#  16  NACIONALIDAD           335135 non-null  int64
#  17  EMBARAZO               335135 non-null  int64
#  18  HABLA_LENGUA_INDIG     335135 non-null  int64
#  19  INDIGENA               335135 non-null  int64
#  20  DIABETES               335135 non-null  int64
#  21  EPOC                   335135 non-null  int64
#  22  ASMA                   335135 non-null  int64
#  23  INMUSUPR               335135 non-null  int64
#  24  HIPERTENSION           335135 non-null  int64
#  25  OTRA_COM               335135 non-null  int64
#  26  CARDIOVASCULAR         335135 non-null  int64
#  27  OBESIDAD               335135 non-null  int64
#  28  RENAL_CRONICA          335135 non-null  int64
#  29  TABAQUISMO             335135 non-null  int64
#  30  OTRO_CASO              335135 non-null  int64
#  31  TOMA_MUESTRA_LAB       335135 non-null  int64
#  32  RESULTADO_LAB          335135 non-null  int64
#  33  TOMA_MUESTRA_ANTIGENO  335135 non-null  int64
#  34  RESULTADO_ANTIGENO     335135 non-null  int64
#  35  CLASIFICACION_FINAL    335135 non-null  int64
#  36  MIGRANTE               335135 non-null  int64
#  37  PAIS_NACIONALIDAD      335135 non-null  object
#  38  PAIS_ORIGEN            335135 non-null  object
#  39  UCI                    335135 non-null  int64
#  40  Dias_Ing               335135 non-null  float64
#  41  Dias_Def               335135 non-null  float64
# dtypes: float64(2), int64(33), object(7)
# memory usage: 109.9+ MB

# %%
# Pienso que estas son las variables relevantes de la tabla:
# 'ENTIDAD_UM', 'ENTIDAD_RES', 'SEXO', 'EDAD', 'EMBARAZO', 'INDIGENA', 
# 'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM', 
# 'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
# 'UCI', 'INTUBADO', 'Dias_Ing', 'Dias_Def'

Defunciones_KM.head()
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 77             2021-10-31      z49a69       1      12          23     1
# 138            2021-10-31      1236ca       1       3          15     2
# 159            2021-10-31      12914d       1      12          32     1
# 209            2021-10-31      0a7fa2       1      12          28     2
# 24059          2021-10-31      06f865       1       4           5     2
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 77              23           23              4              2    2020-07-20
# 138             15           15             60              2    2020-12-14
# 159             32           32             56              2    2020-12-15
# 209             30           28             32              2    2020-06-28
# 24059            5            5             18              2    2020-03-16
#
#       FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 77        2020-07-17  2020-07-21         1         1    66             1
# 138       2020-12-12  2020-12-17         2         1    58             1
# 159       2020-12-15  2020-12-15         2         1    30             1
# 209       2020-06-22  2020-06-28         2         1    53             1
# 24059     2020-03-16  2020-03-28         2         1    47             1
#
#        EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  INMUSUPR  \
# 77            2                   2         2         1     2     2         2
# 138          97                  99        99         1     2     2         2
# 159           2                   2         2         2     2     2         2
# 209          97                   2         2         1     2     2         2
# 24059        97                   2         2         1     2     2         2
#
#        HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 77                1         2               2         1              2
# 138               1         2               1         2              1
# 159               2         2               2         2              1
# 209               1        98              98         1             98
# 24059             1         2               2         2              2
#
#        TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# 77              2          1                 2             97
# 138             2          2                 1              1
# 159             2          2                 1              1
# 209             1          1                 1              1
# 24059           2         99                 1              1
#
#        TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  \
# 77                         2                  97                    2
# 138                        2                  97                    3
# 159                        2                  97                    3
# 209                        2                  97                    3
# 24059                      2                  97                    3
#
#        MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN  UCI  Dias_Ing  Dias_Def
# 77           99           MÃ©xico          97    1      3.00      4.00
# 138          99           MÃ©xico          97    2      2.00      5.00
# 159          99           MÃ©xico          97    2      0.00      0.00
# 209          99           MÃ©xico          97    2      6.00      6.00
# 24059        99           MÃ©xico          97    2      0.00     12.00

# %%
# 

Defunciones_KM.ENTIDAD_UM.value_counts(normalize = True)
# Out:
# ENTIDAD_UM
# 9    0.17
# 15   0.11
# 14   0.06
# 30   0.05
# 21   0.05
# 19   0.05
# 11   0.05
# 2    0.04
# 26   0.03
# 8    0.03
# 25   0.03
# 5    0.03
# 16   0.03
# 28   0.03
# 13   0.03
# 24   0.02
# 31   0.02
# 22   0.02
# 12   0.02
# 27   0.02
# 20   0.02
# 17   0.02
# 23   0.01
# 32   0.01
# 1    0.01
# 10   0.01
# 18   0.01
# 29   0.01
# 3    0.01
# 6    0.01
# 7    0.01
# 4    0.01
# Name: proportion, dtype: float64

# %%
# 

Defunciones_KM.ENTIDAD_RES.value_counts(normalize=True)
# Out:
# ENTIDAD_RES
# 15   0.14
# 9    0.13
# 14   0.06
# 30   0.05
# 21   0.05
# 19   0.05
# 11   0.05
# 2    0.04
# 26   0.03
# 8    0.03
# 25   0.03
# 5    0.03
# 16   0.03
# 13   0.03
# 28   0.03
# 24   0.02
# 31   0.02
# 12   0.02
# 22   0.02
# 20   0.02
# 27   0.02
# 17   0.02
# 23   0.01
# 32   0.01
# 10   0.01
# 1    0.01
# 18   0.01
# 29   0.01
# 3    0.01
# 7    0.01
# 4    0.01
# 6    0.01
# Name: proportion, dtype: float64

# %%
# 

Defunciones_KM.SEXO.value_counts(normalize = True)
# Out:
# SEXO
# 2   0.62
# 1   0.38
# Name: proportion, dtype: float64

# %%
# 

Defunciones_KM.EDAD.value_counts(normalize = True)
# Out:
# EDAD
# 65    0.03
# 67    0.03
# 68    0.03
# 63    0.03
# 66    0.03
#       ...
# 107   0.00
# 110   0.00
# 109   0.00
# 121   0.00
# 119   0.00
# Name: proportion, Length: 113, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM['EDAD'] <= 100 ]

Defunciones_KM.shape
# Out:
# (335000, 42)

# %%
# 

Defunciones_KM.EMBARAZO.value_counts(normalize = True)
# Out:
# EMBARAZO
# 97   0.62
# 2    0.38
# 1    0.00
# 98   0.00
# 99   0.00
# Name: proportion, dtype: float64

# %%
# 

Defunciones_KM.INDIGENA.value_counts(normalize = True)
# Out:
# INDIGENA
# 2    0.96
# 99   0.02
# 1    0.02
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["INDIGENA"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (326993, 42)

# %%
# 

Defunciones_KM.DIABETES.value_counts(normalize = True)
# Out:
# DIABETES
# 2    0.63
# 1    0.37
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["DIABETES"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (325451, 42)

# %%
# 

Defunciones_KM.EPOC.value_counts(normalize = True)
# Out:
# EPOC
# 2    0.95
# 1    0.04
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["EPOC"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (325213, 42)

# %%
# 

Defunciones_KM.ASMA.value_counts(normalize = True)
# Out:
# ASMA
# 2    0.98
# 1    0.02
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["ASMA"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (325156, 42)

# %%
# 

Defunciones_KM.INMUSUPR.value_counts(normalize = True)
# Out:
# INMUSUPR
# 2    0.98
# 1    0.02
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["INMUSUPR"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (325066, 42)

# %%
# 

Defunciones_KM.HIPERTENSION.value_counts(normalize = True)
# Out:
# HIPERTENSION
# 2    0.56
# 1    0.44
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["HIPERTENSION"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (325003, 42)

# %%
# 

Defunciones_KM.OTRA_COM.value_counts(normalize = True)
# Out:
# OTRA_COM
# 2    0.94
# 1    0.05
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["OTRA_COM"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (323504, 42)

# %%
# 

Defunciones_KM.CARDIOVASCULAR.value_counts(normalize = True)
# Out:
# CARDIOVASCULAR
# 2    0.95
# 1    0.05
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["CARDIOVASCULAR"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (323436, 42)

# %%
# 

Defunciones_KM.OBESIDAD.value_counts(normalize = True)
# Out:
# OBESIDAD
# 2    0.80
# 1    0.20
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["OBESIDAD"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (323294, 42)

# %%
# 

Defunciones_KM.RENAL_CRONICA.value_counts(normalize = True)
# Out:
# RENAL_CRONICA
# 2    0.93
# 1    0.07
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["RENAL_CRONICA"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (323232, 42)

# %%
# 

Defunciones_KM.TABAQUISMO.value_counts(normalize = True)
# Out:
# TABAQUISMO
# 2    0.93
# 1    0.07
# 98   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["TABAQUISMO"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (323121, 42)

# %%
# 

Defunciones_KM.UCI.value_counts(normalize = True)
# Out:
# UCI
# 2    0.86
# 1    0.09
# 97   0.04
# 99   0.01
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["UCI"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (306904, 42)

# %%
# 

Defunciones_KM.INTUBADO.value_counts(normalize = True)
# Out:
# INTUBADO
# 2    0.78
# 1    0.22
# 99   0.00
# Name: proportion, dtype: float64

# %%
#

Defunciones_KM = Defunciones_KM[ Defunciones_KM["INTUBADO"].isin( [1, 2] ) ]

Defunciones_KM.shape
# Out:
# (306892, 42)

# %%
# 

Defunciones_KM[ ['Dias_Ing', 'Dias_Def']].describe()
# Out:
#         Dias_Ing   Dias_Def
# count 306,892.00 306,892.00
# mean        5.31      13.79
# std         4.03      11.04
# min       -13.00     -37.00
# 25%         2.00       7.00
# 50%         5.00      12.00
# 75%         7.00      18.00
# max       328.00     466.00

# %%
#

Defunciones_KM = Defunciones_KM[ ( Defunciones_KM['Dias_Ing'] >= 0 ) & ( Defunciones_KM['Dias_Ing'] <= 20 ) & \
                                 ( Defunciones_KM['Dias_Def'] >= 0 ) & ( Defunciones_KM['Dias_Def'] <= 60 ) ]

Defunciones_KM.shape
# Out:
# (305083, 42)

# %%
# 

Defunciones_KM[ ['Dias_Ing', 'Dias_Def']].describe()
# Out:
#         Dias_Ing   Dias_Def
# count 305,083.00 305,083.00
# mean        5.24      13.46
# std         3.80       8.66
# min         0.00       0.00
# 25%         2.00       7.00
# 50%         5.00      12.00
# 75%         7.00      18.00
# max        20.00      60.00

# %%
# Let's see our data in a detailed way with pairplot

sns.pairplot( Defunciones_KM[ [ 'SEXO','EDAD', 'Dias_Ing', 'Dias_Def' ] ] , hue = 'SEXO' )

plt.show()

# %%
# Let's see our data in a detailed way with pairplot

sns.pairplot( Defunciones_KM[ [ 'DIABETES','EDAD', 'Dias_Ing', 'Dias_Def' ] ] , hue = 'DIABETES' )

plt.show()

# %%
# Let's see our data in a detailed way with pairplot

sns.pairplot( Defunciones_KM[ [ 'HIPERTENSION','EDAD', 'Dias_Ing', 'Dias_Def' ] ] , hue = 'HIPERTENSION' )

plt.show()

# %% [markdown]
# De los gráficos anteriores vemos que el género y otras variables no parecen tener relación directa con la segmentación de defunciones. Es por eso que podemos dejarlo y continuar con otras características, razón por la cual usaremos el parámetro X de ahora en adelante.

# %%
# Definimos X:

X = Defunciones_KM [ [ 'ID_REGISTRO', 'ENTIDAD_UM', 'ENTIDAD_RES', 'SEXO', 'EDAD', 'INDIGENA', 
                       'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM', 
                       'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
                       'UCI', 'INTUBADO', 'Dias_Ing', 'Dias_Def' ] ]

# %%
# 

km = KMeans( n_clusters = 3 ).fit( X.drop(['ID_REGISTRO'], axis = 1) )

km.inertia_ #km.labels_
# Out:
# 72737361.86334649

# %%
#

clusters = []

#
for i in range(1, 11):
    km = KMeans( n_clusters = i ).fit( X.drop(['ID_REGISTRO'], axis = 1) )
    clusters.append( km.inertia_ )

#
fig, ax = plt.subplots( figsize = (12, 8) )
sns.lineplot(x = list(range(1, 11)), y = clusters, ax = ax)
ax.set_title('Searching for Elbow')
ax.set_xlabel('Clusters')
ax.set_ylabel('Inertia')

# Annotate arrow
ax.annotate('Possible Elbow Point', xy = (2, 91797400), xytext = (2, 110000000), xycoords = 'data',          
             arrowprops = dict( arrowstyle = '->', connectionstyle = 'arc3', color = 'blue', lw = 2))

ax.annotate('Possible Elbow Point', xy = (3, 72737691), xytext = (3, 90000000), xycoords = 'data',          
             arrowprops = dict( arrowstyle = '->', connectionstyle = 'arc3', color = 'blue', lw = 2))

plt.show()

# %% [markdown]
# El método del codo nos dice que seleccionemos el grupo cuando hay un cambio significativo en la inercia. Como podemos ver en el gráfico, podemos decir que puede ser 2, 3 o 6. Veamos ambos resultados en el gráfico y decidamos.

# %%
# 2 cluster
km2 = KMeans(n_clusters = 2).fit( X.drop(['ID_REGISTRO'], axis = 1) )

X['Labels'] = km2.labels_ 

plt.figure( figsize = (12, 8) )

sns.scatterplot( data = X, x = 'EDAD', y = 'Dias_Def', hue = 'Labels' )

plt.title('KMeans with 2 Clusters')

plt.show()

# %%
# 3 cluster
km3 = KMeans(n_clusters = 3).fit( X.drop(['ID_REGISTRO'], axis = 1) )

X['Labels'] = km3.labels_ 

plt.figure( figsize = (12, 8) )

sns.scatterplot( data = X, x = 'EDAD', y = 'Dias_Def', hue = 'Labels' )

plt.title('KMeans with 3 Clusters')

plt.show()

# %%
# 6 cluster
km6 = KMeans(n_clusters = 6).fit( X.drop(['ID_REGISTRO'], axis = 1) )

X['Labels'] = km6.labels_ 

plt.figure( figsize = (12, 8) )

sns.scatterplot( data = X, x = 'EDAD', y = 'Dias_Def', hue = 'Labels' )

plt.title('KMeans with 6 Clusters')

plt.show()

# %%
#

X[ X['Labels'] == 0].describe()
# Out:
#        ENTIDAD_UM  ENTIDAD_RES      SEXO      EDAD  INDIGENA  DIABETES  \
# count   75,953.00    75,953.00 75,953.00 75,953.00 75,953.00 75,953.00
# mean        10.76        11.09      1.61     59.78      1.99      1.59
# std          4.45         4.51      0.49      5.96      0.10      0.49
# min          1.00         1.00      1.00     45.00      1.00      1.00
# 25%          9.00         9.00      1.00     55.00      2.00      1.00
# 50%         11.00        11.00      2.00     60.00      2.00      2.00
# 75%         15.00        15.00      2.00     65.00      2.00      2.00
# max         32.00        32.00      2.00     69.00      2.00      2.00
#
#            EPOC      ASMA  INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  \
# count 75,953.00 75,953.00 75,953.00     75,953.00 75,953.00       75,953.00
# mean       1.97      1.98      1.98          1.57      1.95            1.96
# std        0.18      0.12      0.15          0.50      0.21            0.20
# min        1.00      1.00      1.00          1.00      1.00            1.00
# 25%        2.00      2.00      2.00          1.00      2.00            2.00
# 50%        2.00      2.00      2.00          2.00      2.00            2.00
# 75%        2.00      2.00      2.00          2.00      2.00            2.00
# max        2.00      2.00      2.00          2.00      2.00            2.00
#
#        OBESIDAD  RENAL_CRONICA  TABAQUISMO       UCI  INTUBADO  Dias_Ing  \
# count 75,953.00      75,953.00   75,953.00 75,953.00 75,953.00 75,953.00
# mean       1.78           1.91        1.92      1.92      1.78      4.56
# std        0.41           0.28        0.27      0.27      0.41      3.41
# min        1.00           1.00        1.00      1.00      1.00      0.00
# 25%        2.00           2.00        2.00      2.00      2.00      2.00
# 50%        2.00           2.00        2.00      2.00      2.00      4.00
# 75%        2.00           2.00        2.00      2.00      2.00      7.00
# max        2.00           2.00        2.00      2.00      2.00     19.00
#
#        Dias_Def    Labels
# count 75,953.00 75,953.00
# mean      10.19      0.00
# std        5.11      0.00
# min        0.00      0.00
# 25%        6.00      0.00
# 50%       10.00      0.00
# 75%       14.00      0.00
# max       25.00      0.00

# %%
#

X[ X['Labels'] == 1].describe()
# Out:
#        ENTIDAD_UM  ENTIDAD_RES      SEXO      EDAD  INDIGENA  DIABETES  \
# count   37,100.00    37,100.00 37,100.00 37,100.00 37,100.00 37,100.00
# mean        13.85        14.17      1.66     37.32      1.99      1.79
# std          6.36         6.26      0.47      9.43      0.12      0.41
# min          1.00         1.00      1.00      0.00      1.00      1.00
# 25%          9.00         9.00      1.00     33.00      2.00      2.00
# 50%         14.00        15.00      2.00     39.00      2.00      2.00
# 75%         17.00        17.00      2.00     44.00      2.00      2.00
# max         32.00        32.00      2.00     50.00      2.00      2.00
#
#            EPOC      ASMA  INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  \
# count 37,100.00 37,100.00 37,100.00     37,100.00 37,100.00       37,100.00
# mean       1.99      1.98      1.96          1.78      1.94            1.98
# std        0.10      0.14      0.19          0.42      0.23            0.15
# min        1.00      1.00      1.00          1.00      1.00            1.00
# 25%        2.00      2.00      2.00          2.00      2.00            2.00
# 50%        2.00      2.00      2.00          2.00      2.00            2.00
# 75%        2.00      2.00      2.00          2.00      2.00            2.00
# max        2.00      2.00      2.00          2.00      2.00            2.00
#
#        OBESIDAD  RENAL_CRONICA  TABAQUISMO       UCI  INTUBADO  Dias_Ing  \
# count 37,100.00      37,100.00   37,100.00 37,100.00 37,100.00 37,100.00
# mean       1.74           1.91        1.93      1.88      1.73      5.30
# std        0.44           0.28        0.25      0.33      0.44      3.86
# min        1.00           1.00        1.00      1.00      1.00      0.00
# 25%        1.00           2.00        2.00      2.00      1.00      2.00
# 50%        2.00           2.00        2.00      2.00      2.00      5.00
# 75%        2.00           2.00        2.00      2.00      2.00      8.00
# max        2.00           2.00        2.00      2.00      2.00     20.00
#
#        Dias_Def    Labels
# count 37,100.00 37,100.00
# mean      13.28      1.00
# std        7.90      0.00
# min        0.00      1.00
# 25%        7.00      1.00
# 50%       12.00      1.00
# 75%       18.00      1.00
# max       60.00      1.00

# %%
#

X[ X['Labels'] == 2].describe()
# Out:
#        ENTIDAD_UM  ENTIDAD_RES      SEXO      EDAD  INDIGENA  DIABETES  \
# count   33,066.00    33,066.00 33,066.00 33,066.00 33,066.00 33,066.00
# mean        13.06        13.50      1.63     64.04      1.99      1.64
# std          6.14         6.05      0.48      8.43      0.11      0.48
# min          1.00         1.00      1.00     29.00      1.00      1.00
# 25%          9.00         9.00      1.00     58.00      2.00      1.00
# 50%         13.00        14.00      2.00     65.00      2.00      2.00
# 75%         16.00        16.00      2.00     70.00      2.00      2.00
# max         32.00        32.00      2.00     95.00      2.00      2.00
#
#            EPOC      ASMA  INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  \
# count 33,066.00 33,066.00 33,066.00     33,066.00 33,066.00       33,066.00
# mean       1.96      1.98      1.98          1.57      1.95            1.96
# std        0.19      0.13      0.14          0.50      0.22            0.21
# min        1.00      1.00      1.00          1.00      1.00            1.00
# 25%        2.00      2.00      2.00          1.00      2.00            2.00
# 50%        2.00      2.00      2.00          2.00      2.00            2.00
# 75%        2.00      2.00      2.00          2.00      2.00            2.00
# max        2.00      2.00      2.00          2.00      2.00            2.00
#
#        OBESIDAD  RENAL_CRONICA  TABAQUISMO       UCI  INTUBADO  Dias_Ing  \
# count 33,066.00      33,066.00   33,066.00 33,066.00 33,066.00 33,066.00
# mean       1.80           1.95        1.92      1.84      1.66      7.81
# std        0.40           0.21        0.28      0.37      0.47      4.32
# min        1.00           1.00        1.00      1.00      1.00      0.00
# 25%        2.00           2.00        2.00      2.00      1.00      5.00
# 50%        2.00           2.00        2.00      2.00      2.00      7.00
# 75%        2.00           2.00        2.00      2.00      2.00     11.00
# max        2.00           2.00        2.00      2.00      2.00     20.00
#
#        Dias_Def    Labels
# count 33,066.00 33,066.00
# mean      29.11      2.00
# std        8.23      0.00
# min       16.00      2.00
# 25%       23.00      2.00
# 50%       27.00      2.00
# 75%       33.00      2.00
# max       60.00      2.00

# %%
#

X[ X['Labels'] == 3].describe()
# Out:
#        ENTIDAD_UM  ENTIDAD_RES      SEXO      EDAD  INDIGENA  DIABETES  \
# count   64,540.00    64,540.00 64,540.00 64,540.00 64,540.00 64,540.00
# mean        10.67        10.96      1.60     79.02      1.99      1.63
# std          4.39         4.44      0.49      6.52      0.10      0.48
# min          1.00         1.00      1.00     69.00      1.00      1.00
# 25%          9.00         9.00      1.00     74.00      2.00      1.00
# 50%         10.00        11.00      2.00     78.00      2.00      2.00
# 75%         14.00        15.00      2.00     83.00      2.00      2.00
# max         32.00        32.00      2.00    100.00      2.00      2.00
#
#            EPOC      ASMA  INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  \
# count 64,540.00 64,540.00 64,540.00     64,540.00 64,540.00       64,540.00
# mean       1.92      1.99      1.98          1.47      1.94            1.92
# std        0.28      0.11      0.14          0.50      0.24            0.27
# min        1.00      1.00      1.00          1.00      1.00            1.00
# 25%        2.00      2.00      2.00          1.00      2.00            2.00
# 50%        2.00      2.00      2.00          1.00      2.00            2.00
# 75%        2.00      2.00      2.00          2.00      2.00            2.00
# max        2.00      2.00      2.00          2.00      2.00            2.00
#
#        OBESIDAD  RENAL_CRONICA  TABAQUISMO       UCI  INTUBADO  Dias_Ing  \
# count 64,540.00      64,540.00   64,540.00 64,540.00 64,540.00 64,540.00
# mean       1.86           1.93        1.91      1.93      1.83      4.68
# std        0.34           0.25        0.29      0.26      0.37      3.58
# min        1.00           1.00        1.00      1.00      1.00      0.00
# 25%        2.00           2.00        2.00      2.00      2.00      2.00
# 50%        2.00           2.00        2.00      2.00      2.00      4.00
# 75%        2.00           2.00        2.00      2.00      2.00      7.00
# max        2.00           2.00        2.00      2.00      2.00     20.00
#
#        Dias_Def    Labels
# count 64,540.00 64,540.00
# mean      10.85      3.00
# std        5.94      0.00
# min        0.00      3.00
# 25%        6.00      3.00
# 50%       10.00      3.00
# 75%       15.00      3.00
# max       41.00      3.00

# %%
#

X[ X['Labels'] == 4].describe()
# Out:
#        ENTIDAD_UM  ENTIDAD_RES      SEXO      EDAD  INDIGENA  DIABETES  \
# count   45,196.00    45,196.00 45,196.00 45,196.00 45,196.00 45,196.00
# mean        25.56        25.56      1.61     54.79      1.97      1.59
# std          4.06         4.05      0.49      7.20      0.16      0.49
# min          4.00         4.00      1.00     30.00      1.00      1.00
# 25%         22.00        22.00      1.00     50.00      2.00      1.00
# 50%         26.00        26.00      2.00     56.00      2.00      2.00
# 75%         30.00        30.00      2.00     61.00      2.00      2.00
# max         32.00        32.00      2.00     66.00      2.00      2.00
#
#            EPOC      ASMA  INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  \
# count 45,196.00 45,196.00 45,196.00     45,196.00 45,196.00       45,196.00
# mean       1.98      1.98      1.98          1.58      1.95            1.97
# std        0.15      0.15      0.15          0.49      0.21            0.18
# min        1.00      1.00      1.00          1.00      1.00            1.00
# 25%        2.00      2.00      2.00          1.00      2.00            2.00
# 50%        2.00      2.00      2.00          2.00      2.00            2.00
# 75%        2.00      2.00      2.00          2.00      2.00            2.00
# max        2.00      2.00      2.00          2.00      2.00            2.00
#
#        OBESIDAD  RENAL_CRONICA  TABAQUISMO       UCI  INTUBADO  Dias_Ing  \
# count 45,196.00      45,196.00   45,196.00 45,196.00 45,196.00 45,196.00
# mean       1.73           1.92        1.95      1.89      1.76      5.48
# std        0.44           0.27        0.22      0.31      0.43      3.65
# min        1.00           1.00        1.00      1.00      1.00      0.00
# 25%        1.00           2.00        2.00      2.00      2.00      3.00
# 50%        2.00           2.00        2.00      2.00      2.00      5.00
# 75%        2.00           2.00        2.00      2.00      2.00      8.00
# max        2.00           2.00        2.00      2.00      2.00     20.00
#
#        Dias_Def    Labels
# count 45,196.00 45,196.00
# mean      13.06      4.00
# std        7.11      0.00
# min        0.00      4.00
# 25%        8.00      4.00
# 50%       12.00      4.00
# 75%       18.00      4.00
# max       51.00      4.00

# %%
#

X[ X['Labels'] == 5].describe()
# Out:
#        ENTIDAD_UM  ENTIDAD_RES      SEXO      EDAD  INDIGENA  DIABETES  \
# count   49,228.00    49,228.00 49,228.00 49,228.00 49,228.00 49,228.00
# mean        25.17        25.19      1.59     76.27      1.97      1.60
# std          4.21         4.20      0.49      7.13      0.17      0.49
# min          5.00         4.00      1.00     65.00      1.00      1.00
# 25%         21.00        21.00      1.00     70.00      2.00      1.00
# 50%         25.00        25.00      2.00     75.00      2.00      2.00
# 75%         30.00        30.00      2.00     81.00      2.00      2.00
# max         32.00        32.00      2.00    100.00      2.00      2.00
#
#            EPOC      ASMA  INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  \
# count 49,228.00 49,228.00 49,228.00     49,228.00 49,228.00       49,228.00
# mean       1.94      1.98      1.98          1.45      1.94            1.92
# std        0.24      0.13      0.14          0.50      0.23            0.27
# min        1.00      1.00      1.00          1.00      1.00            1.00
# 25%        2.00      2.00      2.00          1.00      2.00            2.00
# 50%        2.00      2.00      2.00          1.00      2.00            2.00
# 75%        2.00      2.00      2.00          2.00      2.00            2.00
# max        2.00      2.00      2.00          2.00      2.00            2.00
#
#        OBESIDAD  RENAL_CRONICA  TABAQUISMO       UCI  INTUBADO  Dias_Ing  \
# count 49,228.00      49,228.00   49,228.00 49,228.00 49,228.00 49,228.00
# mean       1.84           1.93        1.94      1.92      1.83      5.05
# std        0.37           0.25        0.24      0.27      0.38      3.62
# min        1.00           1.00        1.00      1.00      1.00      0.00
# 25%        2.00           2.00        2.00      2.00      2.00      2.00
# 50%        2.00           2.00        2.00      2.00      2.00      5.00
# 75%        2.00           2.00        2.00      2.00      2.00      7.00
# max        2.00           2.00        2.00      2.00      2.00     20.00
#
#        Dias_Def    Labels
# count 49,228.00 49,228.00
# mean      11.92      5.00
# std        6.81      0.00
# min        0.00      5.00
# 25%        7.00      5.00
# 50%       11.00      5.00
# 75%       16.00      5.00
# max       48.00      5.00
